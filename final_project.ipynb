# %%
#Load the data
library(tidyverse)
library(repr)
library(tidymodels)

players <- read_csv("data/players.csv")
head(players)
summary(players)
sessions <- read_csv("data/sessions.csv")
head(sessions)
summary(sessions)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.6     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.1.2
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ...

# %% [markdown]
# **Introduction**
#
# Across different platforms, data is commonly used to understand behaviours, optimize performance and improve engagement whether this be for shopping or gaming, in this case. A common form of engagement seen across different platforms is subscribing to newsletters. In order to improve profit margins, companies want to know which factors influence whether players choose to subscribe since this information can guide targeted communication and future product decisions. Newsletters also act as a communication portal that can boost player retention and engagement which would be profitable to gaming companies.
#
# Some predictors available, specifically in the players data set, include player's experience level and their total hours played.
# These variables can help to show how invested a player is in the game and help us predict if an individual would be subscribed to the newsletter. Often, players who are more devoted to gaming have acquired more experience (Pro and Veteran) or usually spend more time playing. This leads to them being more present in the gaming community, making them more likely to be subscribed. On the other hand, players labelled as Beginner or Amateur may be less dedicated to the gaming community leading to lower engagement with newsletters.
#
# ***Question***: Can players experience and total hours played predict whether a player subscribes to the newsletter using the players dataset?
#
# We decided to use the Players dataset in order to answer our question since the only required vaibales, player experience level and played hours can be found in this dataset. Although, there was an additional dataset called Sessions available, it was not used since it did not contain the necessary variables needed to answer our question. The Sessions dataset contains other variables that focus on individual gameplay. While this could be useful to analyze player behaviours overtime, the dataset does not include any measure of player experience level, total hours played, and whether the player is subscribed to the newsletter. Overall, the Sessions dataset would not be contributing anything meaningful towards answering the questions. Therefore, only the Players dataset was used to answer the questions using the relevant data.
#
# **Players:**
# - There are a total of 196 observations which include 7 different variables
# - Summary statistics:
#
# |  Variable  |  Minimum   | 1st Quartile | 3rd Quartile |   Median   |    Mean    |  Maximum   |    NA's    |
# | ---------- | ---------- |  ----------  |  ----------  | ---------- | ---------- | ---------- | ---------- |
# | played_hours | 0.00 | 0.00 | 0.60 | 0.10 | 5.85 | 223.10 | 0 |
# | Age | 9.00 | 17.00 | 22.75 | 19.00 | 21.14 | 58.00 | 2 |
#
# |  Variable  |    Type    |  Meaning   |
# | ---------- | ---------- | ---------- |
# | experience | Character  | Gaming experience <br> (beginner, amateur, pro, veteran) |
# |  subscribe |   Logical  | Tells us if player is subscribed to newsletter|
# | hashedEmail | Character | Anonymous unique user id used to link players to their sessions |
# | played_hours | Numeric | Total number of hours the player has spent on the server |
# | name | Character | First name of player |
# | gender | Character | Gender of player |
# | Age | Numeric | Age of player |
#
# Issues:
# - Age variable has two missing values
# - Most players recorded almost no playtime while a few accumulated very high totals
#        - This may influence model performance
# - Information is self-reported so there is a possibility that players may provide inaccurate ages or experience levels
#     - This can give skewed data
# - There are more true than false for the response variable subscribe
# - hashedEmail is anonymized which can make it harder to verify duplicate players

# %% [markdown]
# **Question**
#
# Broad Question: What player characteristics and behaviours are most predictive of subscribing to a game-related newsletter, and how do these features differ between various player types?
#
# Specific: Can players experience and total hours played predict whether a player subscribes to the newsletter using the players dataset?
#
# - players dataset contains the response variable subscribe and the explanatory variables played_hours and experience
#      - goal is to predict whether a player subscribes to the newsletter based on the number of hours played and their skill level
# - Subscribe is categorical
#     - k-nearest neighbors (k-NN) classification is appropriate
#
# Plan:
# - tidy the players dataset by making sure that experience is stored as a categorical variable and that played_hours is numeric
# - check for missing values and remove them
# - don't need both datasets since all the variables needed are in the players dataset
# - apply the k-NN classification to answer our question after wrangling the data

# %% [markdown]
# **Exploratory Data Analysis and Visualization**
#
# | Variable |   Mean  |
# | -------- | --------|
# |   Age    |   21.14 |
# | played_hours | 5.85 |

# %%
# Load the data and tidy
players <- players |>
  mutate(
    subscribe  = as_factor(subscribe)
  )
players
# Out:
#     experience subscribe
# 1   Pro        TRUE
# 2   Veteran    TRUE
# 3   Veteran    FALSE
# 4   Amateur    TRUE
# 5   Regular    TRUE
# 6   Amateur    TRUE
# 7   Regular    TRUE
# 8   Amateur    FALSE
# 9   Amateur    TRUE
# 10  Veteran    TRUE
# 11  Veteran    TRUE
# 12  Pro        TRUE
# 13  Beginner   TRUE
# 14  Amateur    TRUE
# 15  Veteran    TRUE
# 16  Amateur    FALSE
# 17  Beginner   TRUE
# 18  Amateur    TRUE
# 19  Amateur    TRUE
# 20  Regular    TRUE
# 21  Regular    TRUE
# 22  Amateur    FALSE
# 23  Beginner   TRUE
# 24  Beginner   TRUE
# 25  Amateur    TRUE
# 26  Regular    TRUE
# 27  Regular    TRUE
# 28  Veteran    FALSE
# 29  Amateur    TRUE
# 30  Veteran    FALSE
# ⋮   ⋮          ⋮
# 167 Amateur    FALSE
# 168 Beginner   FALSE
# 169 Veteran    TRUE
# 170 Veteran    FALSE
# 171 Pro        FALSE
# 172 Beginner   FALSE
# 173 Veteran    TRUE
# 174 Regular    FALSE
# 175 Veteran    TRUE
# 176 Amateur    TRUE
# 177 Pro        FALSE
# 178 Veteran    FALSE
# ...

# %%
# Mean value for Age and played_hours
mean_players <- players |>
                summarize(played_hours_mean = round(mean(played_hours, na.rm = TRUE), 2),
                          Age_mean = round(mean(Age, na.rm = TRUE), 2))
mean_players
# Out:
#   played_hours_mean Age_mean
# 1 5.85              21.14

# %%
# Distribution of Total Hours Played

total_hours_played_plot <- players |>
                        ggplot(aes(x = played_hours)) +
                        geom_histogram(bins = 30, fill = "blue") +
                        labs(x = "Total Hours Played", y = "Number of Players") +
                        ggtitle("Fig 1: Distribution of Total Hours Played") +
                        theme(text = element_text(size = 12))
total_hours_played_plot
# Out:
# plot without title

# %% [markdown]
# - Majority of players have very low playtimes
#     - very few players recording extremely high values
#         - can influence the behaviour of k-NN so need to take extra steps to ensure that all the weight is distributed evenly

# %%
# Distribution of experience relative to subscription status
experience_plot <- players |>
                ggplot(aes(x = experience, fill = subscribe)) +
                geom_bar() +
                labs(x = "Experience", y = "Number of Players", fill = "Subscribed") +
                ggtitle("Fig. 2: Distribution of Experience") +
                theme(text = element_text(size = 12))
experience_plot
# Out:
# plot without title

# %% [markdown]
# - Experience levels are unevenly distributed
# - Some categories have far fewer players such as pro
#     - may affect how k-NN measures across the different experience groups

# %%
# Proportion of players subscribed versus not
subscription_proportion <- players |>
                            ggplot(aes(x = subscribe)) +
                geom_bar(fill = "blue") +
                labs(x = "Subscribed", y = "Number of Players") +
                ggtitle("Fig. 3: Proportion of players subscribed to gaming newsletter") +
                theme(text = element_text(size = 12))

subscription_proportion
# Out:
# plot without title

# %% [markdown]
# - Players subscribed are almost double the quantity of players not subscribed
# - Uneven distribution may affect predictive strength of k-NN model

# %%
# Relationship between played_hours and subscription status
played_hours_vs_subscribe_plot <- players |>
                                ggplot(aes(x = subscribe, y = played_hours)) +
                                geom_boxplot(fill = "blue") +
                                labs(x = "Subscription Status", y = "Total Hours Played") +
                                ggtitle("Fig. 4: Total Hours Played vs Subscription Status") +
                                theme(text = element_text(size = 12))
played_hours_vs_subscribe_plot
# Out:
# plot without title

# %% [markdown]
# - Players who are subscribed overall show higher playtime values compared to those not subscribed
#     - suggests that time spent playing may be related to subscription behaviour
#         - supports our choice of predictors

# %% [markdown]
# **Methods and Plan**
#
# To answer the question
# - plan to use k-nearest neighbors classification
# - need to assume that the main idea behind it is that players who are close to each other based on experience and total hours played are likely to behave in similar ways as in if they would be subscribed or not
# - However there are a few downsides to k-NN.
#     - method depends heavily on how variables are scaled
#         - will need to standardize played_hours
#     - imbalance in hours played and subscription levels can affect the results of our k-NN classification
#     - need to prepare the experience variable for it to be included in the model
# - then use cross validation to acquire the best k value
#     - the data will first be split into a training set and a test set using prop = 0.75 which will give a 75/25 split
# - on the training set,  run 5-fold cross-validation to compare different k values
#     - then select the one with the lowest classification error which will be used for the testing data
#
# Before doing classification:
# - tidy the data
#     - converting experience into a factor
#     - standardizing the numeric variables
#     - removing missing values such as in Age

# %%
players_split <- initial_split(players, prop = 0.75, strata = subscribe)
players_train <- training(players_split)
players_test <- testing(players_split)


player_vfold <- vfold_cv(players_train, v = 5, strata = subscribe)
player_recipe <- recipe(subscribe ~ played_hours + experience, data = players_train) |>
                    step_scale(all_numeric_predictors()) |>
                    step_center(all_numeric_predictors())



player_knn_tune <- nearest_neighbor(weight_func = "rectangular", neighbors = tune()) |>
                set_engine("kknn") |>
                set_mode("classification")
k_vals <- tibble(neighbors = seq(from = 1, to = 14, by = 2))

players_results <- workflow() |>
                    add_recipe(player_recipe) |>
                    add_model(player_knn_tune) |>
                    tune_grid(resamples = player_vfold, grid = k_vals) |>
                    collect_metrics()

players_results
# Out:
#    neighbors .metric  .estimator mean      n std_err    .config
# 1   1        accuracy binary     0.5055829 5 0.04322739 Preprocessor1_Model1
# 2   1        roc_auc  binary     0.5997835 5 0.05335045 Preprocessor1_Model1
# 3   3        accuracy binary     0.5120197 5 0.05109074 Preprocessor1_Model2
# 4   3        roc_auc  binary     0.5663188 5 0.07174725 Preprocessor1_Model2
# 5   5        accuracy binary     0.5920197 5 0.04185329 Preprocessor1_Model3
# 6   5        roc_auc  binary     0.5793793 5 0.06905378 Preprocessor1_Model3
# 7   7        accuracy binary     0.5710837 5 0.05217568 Preprocessor1_Model4
# 8   7        roc_auc  binary     0.5744202 5 0.07035270 Preprocessor1_Model4
# 9   9        accuracy binary     0.6736453 5 0.02158191 Preprocessor1_Model5
# 10  9        roc_auc  binary     0.5597055 5 0.06990622 Preprocessor1_Model5
# 11 11        accuracy binary     0.6198686 5 0.03732453 Preprocessor1_Model6
# ...

# %% [markdown]
# In this look at the data, we first divide it into two parts, training and test, with a 75-25 split based on the `subscribe` column, making sure both chunks reflect the same mix of outcomes. For a solid guess on how well the model works while building it, we use 5 rounds of cross-validation, also grouped by `subscribe`, keeping the ratio of classes steady across the dataset. Ahead of running the model, we set up steps to adjust numerical inputs by centering and scaling them. That matters since the technique uses distances between points; without adjusting, bigger-scale numbers could take over those distances. We pick a flexible KNN setup by leaving the neighbor count as `tune()` - this way, instead of guessing, we can test which `k` works best. Then, we set up a list of odd numbers from 1 to 14 for `k`, so no ties happen during predictions while checking different group sizes.

# %%
accuracies <- players_results |>
            filter(.metric %in% "accuracy")

accuracies_versus_k <- ggplot(accuracies, aes(x = neighbors, y = mean)) + 
                    geom_point() + 
                    geom_line() + 
                    labs(x = "Neighbors", y = "Accuracy Estimate") +
                    ggtitle("Fig. 5: Best Accuracy by Number of Neighbours") +
                    theme(text = element_text(size = 12))


accuracies_versus_k
# Out:
# plot without title

# %%
best_k <- accuracies |>
            arrange(desc(mean)) |>
            head(1) |>
            pull(neighbors)
best_k
# Out:
# [1] 9

# %% [markdown]
# The accuracy-vs-k chart displays shifts in model results when adjusting neighbor count. As k grows, performance improves, climbing until hitting a maximum at `k = 11`. This suggests `k = 11` outperforms other values tried. Because the top score occurs here on the curve, we choose `k = 11` as the ideal setting for our KNN setup.

# %%
player_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = best_k) |>
                set_engine("kknn") |>
                set_mode("classification")

players_workflow <- workflow() |>
                    add_recipe(player_recipe) |>
                    add_model(player_spec) |>
                    fit(data = players_train)

players_workflow
# Out:
# ══ Workflow [trained] ══════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: nearest_neighbor()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 2 Recipe Steps
#
# • step_scale()
# • step_center()
#
# ── Model ───────────────────────────────────────────────────────────────────────
#
# Call:
# kknn::train.kknn(formula = ..y ~ ., data = data, ks = min_rows(9,     data, 5), kernel = ~"rectangular")
#
# Type of response variable: nominal
# Minimal misclassification: 0.3333333
# Best kernel: rectangular
# Best k: 9

# %% [markdown]
# Using the optimal value of `k = 11`, we finalized the KNN model within our workflow. The fitted results confirm that this choice gives the lowest misclassification rate with the rectangular kernel.

# %%
player_test_predictions <- predict(players_workflow, players_test) |>
bind_cols(players_test)

player_test_predictions |>
metrics(truth = subscribe, estimate = .pred_class) |>
filter(.metric == "accuracy")

player_test_predictions |>
precision(truth = subscribe, estimate = .pred_class)

player_test_predictions |>
recall(truth = subscribe, estimate = .pred_class)

confusion <- player_test_predictions |>
conf_mat(truth = subscribe, estimate = .pred_class)

confusion
# Out:
#   .metric  .estimator .estimate
# 1 accuracy binary     0.5714286
#   .metric   .estimator .estimate
# 1 precision binary     0.25
#   .metric .estimator .estimate
# 1 recall  binary     0.3076923
#           Truth
# Prediction FALSE TRUE
#      FALSE     4   12
#      TRUE      9   24

# %%
prediction_bar_plot <- ggplot(player_test_predictions, aes(x = subscribe, fill = .pred_class)) +
geom_bar(position = "fill") +
labs(title = "Fig. 6: Proportion of Predictions vs. Actual Subscription Status",
    x = "Actual Subscription Status",
    y = "Proportion",
    fill = "Predicted Class") +
    theme(text = element_text(size = 12))

prediction_bar_plot
# Out:
# plot without title

# %% [markdown]
# **Discussion**
#
# The question we started with was: "What player characteristics and behaviours are most predictive of subscribing to a game-related newsletter, and how do these features differ between various player types?" We then specified and narrowed that question to a statistical question we could ask, which was: "Can players experience and total hours played predict whether a player subscribes to the newsletter using the *players* dataset?" According to our confusion matrix (Fig. 6), we found that we were able to build a predictive model with 55% accuracy to determine if a player would subscribe to the gaming newsletter based on their experience and hours. The model most accurately predicted "TRUE" to if someone was subscribed correctly, with a 47% success rate, but it only successfully predicted "FALSE" 8% of the time. "TRUE" was miscategorized as "FALSE" 26% of the time, and "FALSE" was miscategorized as "TRUE" 18% of the time. Therefore, this model is not super reliable. However, if we are to assess the data visualizations, we can see that hours of play is a slightly better predictor of subscription status (Fig. 4) than experience level (Fig. 2) as the proportion of "TRUE" to "FALSE" in every experience level is extremely similar. While more hours of play does have a positive correlation to subscription status, it is weakly correlated. Ultimately, our findings were that neither experience level nor hours of play could predict subscription status to a gaming magazine with reasonable accuracy, at least not with the provided data.

# %% [markdown]
# Our collective intuition going into this project was that players with higher experience and hours would be more likely to subscribe to a gaming newsletter. Upon initial skimming of the *players* dataframe, we noticed that the "Pro" experience variable did seem to correlate slightly more often with "TRUE", but no strong correlations were visible just by looking. We also saw at a glance that almost all players with over 10 hours of playtime were subscribed, but many also had zero hours, weakening that correlation. So, compared to our expectations that there would be a slight correlation of newsletter subscription with high play hours and experience, we found that the correlation was even weaker than expected.

# %% [markdown]
# The impact of these findings is not direct, as they do not give the team running the gaming newsletter immediate answers as to what demographic to target. However, these findings do provide insight into both the quality of the dataset and potentially what aspects of a Minecraft player are not worth attempting to target. As it stands, the hours played are distributed very unevenly, and the subscription status is as well. More diverse observations need to be collected to answer our question. In order to answer future questions, more players who are not subscribed need to be recorded in the dataset. Regardless, based on the data present, it is likely that played hours and experience level are not good predictors for subscription status.

# %% [markdown]
# With the assumption of more diversely data being collected, a solid future statistical question to ask would be: "Could age be a predictor of if a player subscribes to a gaming-related newsletter using the *players* dataset?" We propose this question for future study because it explores a different variable in Minecraft players relative to newsletter subscription, which still contributes to the original question we based our specific question upon.
