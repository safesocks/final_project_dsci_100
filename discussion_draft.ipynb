# %%
# for discussion - planning

# %% [markdown]
# `delete this cell later` **Discussion**:
# - summarize what you found
# - discuss whether this is what you expected to find
# - discuss what impact could such findings have
# - discuss what future questions could this lead to

# %% [markdown]
# `edit this cell with concrete findings + rephrasing where needed`
#
# The question we started with was: "What player characteristics and behaviours are most predictive of subscribing to a game-related newsletter, and how do these features differ between various player types?" We then specified and narrowed that question to a statistical question we could ask, which was: "Can players experience and total hours played predict whether a player subscribes to the newsletter using the players dataset?" We found that [YES/NO], we [COULD/COULD NOT] build a strong predictive model to determine if a player would subscribe to the gaming newsletter based on their experience and hours. `...`
#
# [go into findings here -- did we find that one trait was more indicative than the other? what was the point at which hours made players most likely to sub? what was the experience level most likely to sub? was there a relationship between hours and experience that was most attributed to sub = TRUE?]

# %% [markdown]
# Our collective intuition going into this project was that players with higher experience and hours would be more likely to subscribe to a gaming newsletter. Upon initial skimming of the `players.csv` dataframe, we noticed that the "Pro" experience variable did seem to correlate slightly more often with "TRUE", but no strong correlations were visible just by looking. We also saw at a glance that almost all players with over 10 hours of playtime were subscribed, but many also had zero hours, weakening that correlation. So, compared to our expectations that there would be a slight correlation of newsletter subscription with high play hours and experience, we found that `...`
